# %%
# !pip install torch monai nibabel scikit-learn matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: torch in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (2.7.0)
# Requirement already satisfied: monai in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (1.4.0)
# Requirement already satisfied: nibabel in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (5.3.2)
# Requirement already satisfied: scikit-learn in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (1.4.2)
# Requirement already satisfied: matplotlib in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: filelock in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from torch) (4.13.0)
# Requirement already satisfied: setuptools in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from torch) (75.8.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from torch) (3.3.0)
# Requirement already satisfied: numpy<2.0,>=1.24 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from monai) (1.26.4)
# Requirement already satisfied: packaging>=20 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from nibabel) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/UWO/msnyde26/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /local/software/fsl/6.0.7.17/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)

# %% [markdown]
# Imports

# %%
import torch 
import glob 
import os
import nibabel as nib
from sklearn.model_selection import train_test_split
from nibabel.processing import resample_from_to

import monai
from monai.transforms import (
    Compose,
    LoadImaged,
    EnsureChannelFirstd,
    Rand3DElasticd,
    ScaleIntensityd,
    SpatialPadd,
    CenterSpatialCropd,
    RandFlipd,
    ToTensord,
    MapTransform,
    Resize
)
from monai.data import Dataset, DataLoader
from monai.networks.nets import UNet

import time
import numpy as np

from monai.utils import progress_bar

import matplotlib.pyplot as plt
from monai.inferers import sliding_window_inference
from pathlib import Path

# %% [markdown]
# Model variables

# %%
# To test
# patch_size = (16, 32)
# batch_size = (32, 64, 128)
# lr = (0.0001, 0.001, 0.01)
# filter_num = (16, 32, 64)
# depth = (3, 4)
# num_conv = (2, 3)
# loss_func = "mae"

image_size = 256
batch_size = 1
lr = 0.0001
filter = 64
depth = 4
loss_func = "mae"

# %% [markdown]
# create output directory

# %%
home_dir = Path.home()
output_dir = f"/localscratch/output_whole_images/image-{image_size}_batch-{batch_size}_LR-{lr}_filter-{filter}_depth-{depth}_loss-{loss_func}/"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %% [markdown]
# Resources

# %%
# use gpu if available 
pin_memory = torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /home/UWO/msnyde26/.local/lib/python3.12/site-packages/torch/cuda/__init__.py:174: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11060). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# Move preprocessed data to one input folder

# %%
# creates a dictionary of pairs of image file paths (str)

input_dir = os.path.expanduser("~/graham/scratch/degad_preprocessed_data")

work_dir = os.path.join(input_dir, "work")
subject_dirs = glob.glob(os.path.join(work_dir, "sub-*"))

subjects = []
for directory in subject_dirs:
    if os.path.isdir(directory): 
        subjects.append(directory)

data_dicts = []
for sub in subjects:   
    gad_images = glob.glob(os.path.join(sub, "ses-pre", "normalize", "*acq-gad*_T1w.nii.gz"))
    print("Found gad images:", gad_images)
    
    nogad_images = glob.glob(os.path.join(sub, "ses-pre", "normalize", "*acq-nongad*_T1w.nii.gz"))
    print("Found nogad images:", nogad_images)
    
    if gad_images and nogad_images:
        data_dicts.append({"image": gad_images[0], "label": nogad_images[0], "image_filepath": gad_images[0]})

print("Loaded", len(data_dicts), "paired samples.")
# Out:
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P003/ses-pre/normalize/sub-P003_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P003/ses-pre/normalize/sub-P003_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P004/ses-pre/normalize/sub-P004_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P004/ses-pre/normalize/sub-P004_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P005/ses-pre/normalize/sub-P005_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P005/ses-pre/normalize/sub-P005_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P006/ses-pre/normalize/sub-P006_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P006/ses-pre/normalize/sub-P006_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P007/ses-pre/normalize/sub-P007_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P007/ses-pre/normalize/sub-P007_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P008/ses-pre/normalize/sub-P008_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P008/ses-pre/normalize/sub-P008_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P010/ses-pre/normalize/sub-P010_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P010/ses-pre/normalize/sub-P010_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P011/ses-pre/normalize/sub-P011_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P011/ses-pre/normalize/sub-P011_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P012/ses-pre/normalize/sub-P012_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P012/ses-pre/normalize/sub-P012_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P014/ses-pre/normalize/sub-P014_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P014/ses-pre/normalize/sub-P014_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P015/ses-pre/normalize/sub-P015_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P015/ses-pre/normalize/sub-P015_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P016/ses-pre/normalize/sub-P016_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P016/ses-pre/normalize/sub-P016_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P017/ses-pre/normalize/sub-P017_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P017/ses-pre/normalize/sub-P017_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P018/ses-pre/normalize/sub-P018_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P018/ses-pre/normalize/sub-P018_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P019/ses-pre/normalize/sub-P019_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P019/ses-pre/normalize/sub-P019_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P020/ses-pre/normalize/sub-P020_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P020/ses-pre/normalize/sub-P020_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P021/ses-pre/normalize/sub-P021_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P021/ses-pre/normalize/sub-P021_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P022/ses-pre/normalize/sub-P022_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P022/ses-pre/normalize/sub-P022_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P023/ses-pre/normalize/sub-P023_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P023/ses-pre/normalize/sub-P023_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P024/ses-pre/normalize/sub-P024_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P024/ses-pre/normalize/sub-P024_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P025/ses-pre/normalize/sub-P025_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P025/ses-pre/normalize/sub-P025_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P026/ses-pre/normalize/sub-P026_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P026/ses-pre/normalize/sub-P026_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P028/ses-pre/normalize/sub-P028_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P028/ses-pre/normalize/sub-P028_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P029/ses-pre/normalize/sub-P029_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P029/ses-pre/normalize/sub-P029_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P030/ses-pre/normalize/sub-P030_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P030/ses-pre/normalize/sub-P030_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P031/ses-pre/normalize/sub-P031_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P031/ses-pre/normalize/sub-P031_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P032/ses-pre/normalize/sub-P032_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P032/ses-pre/normalize/sub-P032_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P033/ses-pre/normalize/sub-P033_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P033/ses-pre/normalize/sub-P033_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P034/ses-pre/normalize/sub-P034_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P034/ses-pre/normalize/sub-P034_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P035/ses-pre/normalize/sub-P035_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P035/ses-pre/normalize/sub-P035_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P036/ses-pre/normalize/sub-P036_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P036/ses-pre/normalize/sub-P036_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P037/ses-pre/normalize/sub-P037_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P037/ses-pre/normalize/sub-P037_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P038/ses-pre/normalize/sub-P038_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P038/ses-pre/normalize/sub-P038_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P039/ses-pre/normalize/sub-P039_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P039/ses-pre/normalize/sub-P039_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P041/ses-pre/normalize/sub-P041_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P041/ses-pre/normalize/sub-P041_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P042/ses-pre/normalize/sub-P042_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P042/ses-pre/normalize/sub-P042_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P043/ses-pre/normalize/sub-P043_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P043/ses-pre/normalize/sub-P043_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P044/ses-pre/normalize/sub-P044_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P044/ses-pre/normalize/sub-P044_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P045/ses-pre/normalize/sub-P045_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P045/ses-pre/normalize/sub-P045_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P046/ses-pre/normalize/sub-P046_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P046/ses-pre/normalize/sub-P046_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P047/ses-pre/normalize/sub-P047_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P047/ses-pre/normalize/sub-P047_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P048/ses-pre/normalize/sub-P048_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P048/ses-pre/normalize/sub-P048_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P051/ses-pre/normalize/sub-P051_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P051/ses-pre/normalize/sub-P051_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P052/ses-pre/normalize/sub-P052_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P052/ses-pre/normalize/sub-P052_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P053/ses-pre/normalize/sub-P053_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P053/ses-pre/normalize/sub-P053_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P054/ses-pre/normalize/sub-P054_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P054/ses-pre/normalize/sub-P054_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P055/ses-pre/normalize/sub-P055_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P055/ses-pre/normalize/sub-P055_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P056/ses-pre/normalize/sub-P056_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P056/ses-pre/normalize/sub-P056_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P057/ses-pre/normalize/sub-P057_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P057/ses-pre/normalize/sub-P057_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P058/ses-pre/normalize/sub-P058_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P058/ses-pre/normalize/sub-P058_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P059/ses-pre/normalize/sub-P059_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P059/ses-pre/normalize/sub-P059_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P060/ses-pre/normalize/sub-P060_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P060/ses-pre/normalize/sub-P060_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P061/ses-pre/normalize/sub-P061_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P061/ses-pre/normalize/sub-P061_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P062/ses-pre/normalize/sub-P062_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P062/ses-pre/normalize/sub-P062_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P063/ses-pre/normalize/sub-P063_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P063/ses-pre/normalize/sub-P063_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P064/ses-pre/normalize/sub-P064_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P064/ses-pre/normalize/sub-P064_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P065/ses-pre/normalize/sub-P065_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P065/ses-pre/normalize/sub-P065_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P066/ses-pre/normalize/sub-P066_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P066/ses-pre/normalize/sub-P066_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P068/ses-pre/normalize/sub-P068_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P068/ses-pre/normalize/sub-P068_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P069/ses-pre/normalize/sub-P069_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P069/ses-pre/normalize/sub-P069_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P070/ses-pre/normalize/sub-P070_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P070/ses-pre/normalize/sub-P070_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P071/ses-pre/normalize/sub-P071_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P071/ses-pre/normalize/sub-P071_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P072/ses-pre/normalize/sub-P072_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P072/ses-pre/normalize/sub-P072_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P073/ses-pre/normalize/sub-P073_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P073/ses-pre/normalize/sub-P073_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P074/ses-pre/normalize/sub-P074_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P074/ses-pre/normalize/sub-P074_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P075/ses-pre/normalize/sub-P075_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P075/ses-pre/normalize/sub-P075_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P076/ses-pre/normalize/sub-P076_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P076/ses-pre/normalize/sub-P076_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P077/ses-pre/normalize/sub-P077_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P077/ses-pre/normalize/sub-P077_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P078/ses-pre/normalize/sub-P078_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P078/ses-pre/normalize/sub-P078_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P079/ses-pre/normalize/sub-P079_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P079/ses-pre/normalize/sub-P079_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P081/ses-pre/normalize/sub-P081_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P081/ses-pre/normalize/sub-P081_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P083/ses-pre/normalize/sub-P083_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P083/ses-pre/normalize/sub-P083_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P084/ses-pre/normalize/sub-P084_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P084/ses-pre/normalize/sub-P084_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P085/ses-pre/normalize/sub-P085_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P085/ses-pre/normalize/sub-P085_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P086/ses-pre/normalize/sub-P086_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P086/ses-pre/normalize/sub-P086_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P087/ses-pre/normalize/sub-P087_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P087/ses-pre/normalize/sub-P087_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P088/ses-pre/normalize/sub-P088_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P088/ses-pre/normalize/sub-P088_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P089/ses-pre/normalize/sub-P089_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P089/ses-pre/normalize/sub-P089_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P090/ses-pre/normalize/sub-P090_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P090/ses-pre/normalize/sub-P090_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P091/ses-pre/normalize/sub-P091_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P091/ses-pre/normalize/sub-P091_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P092/ses-pre/normalize/sub-P092_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P092/ses-pre/normalize/sub-P092_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P093/ses-pre/normalize/sub-P093_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P093/ses-pre/normalize/sub-P093_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P095/ses-pre/normalize/sub-P095_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P095/ses-pre/normalize/sub-P095_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P096/ses-pre/normalize/sub-P096_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P096/ses-pre/normalize/sub-P096_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P097/ses-pre/normalize/sub-P097_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P097/ses-pre/normalize/sub-P097_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P098/ses-pre/normalize/sub-P098_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P098/ses-pre/normalize/sub-P098_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P099/ses-pre/normalize/sub-P099_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P099/ses-pre/normalize/sub-P099_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P100/ses-pre/normalize/sub-P100_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P100/ses-pre/normalize/sub-P100_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P101/ses-pre/normalize/sub-P101_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P101/ses-pre/normalize/sub-P101_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P102/ses-pre/normalize/sub-P102_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P102/ses-pre/normalize/sub-P102_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P103/ses-pre/normalize/sub-P103_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P103/ses-pre/normalize/sub-P103_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P104/ses-pre/normalize/sub-P104_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P104/ses-pre/normalize/sub-P104_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P106/ses-pre/normalize/sub-P106_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P106/ses-pre/normalize/sub-P106_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P107/ses-pre/normalize/sub-P107_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P107/ses-pre/normalize/sub-P107_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P108/ses-pre/normalize/sub-P108_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P108/ses-pre/normalize/sub-P108_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P109/ses-pre/normalize/sub-P109_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P109/ses-pre/normalize/sub-P109_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P110/ses-pre/normalize/sub-P110_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P110/ses-pre/normalize/sub-P110_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P111/ses-pre/normalize/sub-P111_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P111/ses-pre/normalize/sub-P111_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P112/ses-pre/normalize/sub-P112_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P112/ses-pre/normalize/sub-P112_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P113/ses-pre/normalize/sub-P113_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P113/ses-pre/normalize/sub-P113_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P114/ses-pre/normalize/sub-P114_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P114/ses-pre/normalize/sub-P114_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P115/ses-pre/normalize/sub-P115_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P115/ses-pre/normalize/sub-P115_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P116/ses-pre/normalize/sub-P116_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P116/ses-pre/normalize/sub-P116_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P117/ses-pre/normalize/sub-P117_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P117/ses-pre/normalize/sub-P117_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P118/ses-pre/normalize/sub-P118_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P118/ses-pre/normalize/sub-P118_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P119/ses-pre/normalize/sub-P119_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P119/ses-pre/normalize/sub-P119_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P120/ses-pre/normalize/sub-P120_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P120/ses-pre/normalize/sub-P120_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P121/ses-pre/normalize/sub-P121_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P121/ses-pre/normalize/sub-P121_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P122/ses-pre/normalize/sub-P122_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P122/ses-pre/normalize/sub-P122_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P123/ses-pre/normalize/sub-P123_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P123/ses-pre/normalize/sub-P123_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P124/ses-pre/normalize/sub-P124_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P124/ses-pre/normalize/sub-P124_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P125/ses-pre/normalize/sub-P125_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P125/ses-pre/normalize/sub-P125_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P126/ses-pre/normalize/sub-P126_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P126/ses-pre/normalize/sub-P126_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P127/ses-pre/normalize/sub-P127_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P127/ses-pre/normalize/sub-P127_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P128/ses-pre/normalize/sub-P128_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P128/ses-pre/normalize/sub-P128_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P129/ses-pre/normalize/sub-P129_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P129/ses-pre/normalize/sub-P129_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P130/ses-pre/normalize/sub-P130_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P130/ses-pre/normalize/sub-P130_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P131/ses-pre/normalize/sub-P131_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P131/ses-pre/normalize/sub-P131_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P132/ses-pre/normalize/sub-P132_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P132/ses-pre/normalize/sub-P132_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P133/ses-pre/normalize/sub-P133_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P133/ses-pre/normalize/sub-P133_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P134/ses-pre/normalize/sub-P134_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P134/ses-pre/normalize/sub-P134_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P135/ses-pre/normalize/sub-P135_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P135/ses-pre/normalize/sub-P135_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P136/ses-pre/normalize/sub-P136_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P136/ses-pre/normalize/sub-P136_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P137/ses-pre/normalize/sub-P137_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P137/ses-pre/normalize/sub-P137_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P138/ses-pre/normalize/sub-P138_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P138/ses-pre/normalize/sub-P138_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P139/ses-pre/normalize/sub-P139_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P139/ses-pre/normalize/sub-P139_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P140/ses-pre/normalize/sub-P140_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P140/ses-pre/normalize/sub-P140_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P141/ses-pre/normalize/sub-P141_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P141/ses-pre/normalize/sub-P141_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P142/ses-pre/normalize/sub-P142_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P142/ses-pre/normalize/sub-P142_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P143/ses-pre/normalize/sub-P143_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P143/ses-pre/normalize/sub-P143_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P144/ses-pre/normalize/sub-P144_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P144/ses-pre/normalize/sub-P144_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P145/ses-pre/normalize/sub-P145_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P145/ses-pre/normalize/sub-P145_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P146/ses-pre/normalize/sub-P146_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P146/ses-pre/normalize/sub-P146_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P147/ses-pre/normalize/sub-P147_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P147/ses-pre/normalize/sub-P147_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P148/ses-pre/normalize/sub-P148_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P148/ses-pre/normalize/sub-P148_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P149/ses-pre/normalize/sub-P149_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P149/ses-pre/normalize/sub-P149_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P150/ses-pre/normalize/sub-P150_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P150/ses-pre/normalize/sub-P150_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P151/ses-pre/normalize/sub-P151_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P151/ses-pre/normalize/sub-P151_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P152/ses-pre/normalize/sub-P152_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P152/ses-pre/normalize/sub-P152_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P154/ses-pre/normalize/sub-P154_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P154/ses-pre/normalize/sub-P154_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P155/ses-pre/normalize/sub-P155_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P155/ses-pre/normalize/sub-P155_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P156/ses-pre/normalize/sub-P156_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P156/ses-pre/normalize/sub-P156_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P157/ses-pre/normalize/sub-P157_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P157/ses-pre/normalize/sub-P157_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P158/ses-pre/normalize/sub-P158_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P158/ses-pre/normalize/sub-P158_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P159/ses-pre/normalize/sub-P159_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P159/ses-pre/normalize/sub-P159_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P160/ses-pre/normalize/sub-P160_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P160/ses-pre/normalize/sub-P160_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P162/ses-pre/normalize/sub-P162_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P162/ses-pre/normalize/sub-P162_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P164/ses-pre/normalize/sub-P164_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P164/ses-pre/normalize/sub-P164_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P165/ses-pre/normalize/sub-P165_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P165/ses-pre/normalize/sub-P165_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P166/ses-pre/normalize/sub-P166_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P166/ses-pre/normalize/sub-P166_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P167/ses-pre/normalize/sub-P167_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P167/ses-pre/normalize/sub-P167_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P168/ses-pre/normalize/sub-P168_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P168/ses-pre/normalize/sub-P168_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P169/ses-pre/normalize/sub-P169_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P169/ses-pre/normalize/sub-P169_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P170/ses-pre/normalize/sub-P170_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P170/ses-pre/normalize/sub-P170_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P171/ses-pre/normalize/sub-P171_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P171/ses-pre/normalize/sub-P171_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P172/ses-pre/normalize/sub-P172_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P172/ses-pre/normalize/sub-P172_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Found gad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P173/ses-pre/normalize/sub-P173_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz']
# Found nogad images: ['/home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P173/ses-pre/normalize/sub-P173_ses-pre_acq-nongad_run-01_desc-normalized_zscore_T1w.nii.gz']
# Loaded 157 paired samples.

# %% [markdown]
# Split into train, test, validate

# %%
# create split of the image path strings

# 70% train, 15% val, 15% test 

train_val, test = train_test_split(data_dicts, test_size=0.15, random_state=42)

# 0.176 ≈ 15% of the full data
train, val = train_test_split(train_val, test_size=0.176, random_state=42)

print(f"Train: {len(train)}, Val: {len(val)}, Test: {len(test)}")
# Out:
# Train: 109, Val: 24, Test: 24

# %%
class SaveImagePath(MapTransform):
    def __init__(self, keys):
        super().__init__(keys)
        
    def __call__(self, data):
        # Storing the file path separately in the 'image_filepath' key
        data['image_filepath'] = data['image']
        return data

# %% [markdown]
# Define transforms

# %%
# using transformations from original code 

# set size of image to patch size (patch_size, patch_size, patch_size)
dims_tuple = (image_size,)*3
print("dims_tuple: ", dims_tuple)

# train tranforms 
train_transforms = Compose([
    LoadImaged(
        keys=["image", "label"], 
    ),  # load image from the file path 
    EnsureChannelFirstd(keys=["image", "label"]), # ensure this is [C, H, W, (D)]
    ScaleIntensityd(keys=["image"]), # scales the intensity from 0-1
    Rand3DElasticd(
        keys = ("image","label"), 
        sigma_range = (0.5,1), 
        magnitude_range = (0.1, 0.4), 
        prob=0.4, 
        shear_range=(0.1, -0.05, 0.0, 0.0, 0.0, 0.0),
        scale_range=0.5, padding_mode= "zeros"
    ),
    RandFlipd(keys = ("image","label"), prob = 0.5, spatial_axis=(0,1,2)),
    SpatialPadd(keys = ("image","label"), spatial_size=dims_tuple), #ensure all images are (1,256,256,256) if too small
    CenterSpatialCropd(keys=("image", "label"), roi_size=dims_tuple), # ensure all images are (1,256,256,256) if too big
    ToTensord(keys=["image", "label"])
])

# view size of image and label for training
sample_train = train_transforms(train[0])
print("Test image shape:", sample_train["image"].shape)
print("Test label shape:", sample_train["label"].shape)

# want to validate and test with whole images 
val_transforms = Compose([
    SaveImagePath(keys=["image"]),
    LoadImaged(
        keys=["image", "label"]
    ),  # load image
    EnsureChannelFirstd(keys=["image", "label"]),
    ScaleIntensityd(keys=["image"]),
    SpatialPadd(keys = ("image","label"), spatial_size=dims_tuple), #ensure all images are (1,256,256,256) if too small
    CenterSpatialCropd(keys=("image", "label"), roi_size=dims_tuple), # ensure all images are (1,256,256,256) if too big
    ToTensord(keys=["image", "label"])
])

sample_val = val_transforms(val[0])
print("Val image shape:", sample_val["image"].shape)
print("Val label shape:", sample_val["label"].shape)

sample_test = val_transforms(test[0])
print("Test image shape:", sample_test["image"].shape)
print("Test label shape:", sample_test["label"].shape)
print("Image file path:", sample_test["image_filepath"])
# Out:
# dims_tuple:  (256, 256, 256)
# Test image shape: torch.Size([1, 256, 256, 256])
# Test label shape: torch.Size([1, 256, 256, 256])
# Val image shape: torch.Size([1, 256, 256, 256])
# Val label shape: torch.Size([1, 256, 256, 256])
# Test image shape: torch.Size([1, 256, 256, 256])
# Test label shape: torch.Size([1, 256, 256, 256])
# Image file path: /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P140/ses-pre/normalize/sub-P140_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz

# %% [markdown]
# Set up datasets and data loader with monai

# %%
train_ds = Dataset(data=train, transform=train_transforms)
val_ds = Dataset(data=val, transform=val_transforms)
test_ds = Dataset(data=test, transform=val_transforms)

# training, validating, testing of whole data so use a batch size of 1
train_loader = DataLoader(train_ds, batch_size=len(train), shuffle=True, num_workers=2, pin_memory=pin_memory)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=2, pin_memory=pin_memory)
test_loader = DataLoader(test_ds, batch_size=1, num_workers=2, pin_memory=pin_memory)

# %%
for batch in test_loader:
    print("Image shape:", batch["image"].shape)
    print("Label shape:", batch["label"].shape)
    break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 for batch in test_loader:
#       2     print("Image shape:", batch["image"].shape)
#       3     print("Label shape:", batch["label"].shape)
#
# File /local/scratch/MRI_Degad_Model/venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File /local/scratch/MRI_Degad_Model/venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1458, in _MultiProcessingDataLoaderIter._next_data(self)
#    1455     return self._process_data(data)
#    1457 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1458 idx, data = self._get_data()
#    1459 self._tasks_outstanding -= 1
#    1460 if self._dataset_kind == _DatasetKind.Iterable:
#    1461     # Check for _IterableDatasetStopIteration
#
# File /local/scratch/MRI_Degad_Model/venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1420, in _MultiProcessingDataLoaderIter._get_data(self)
#    1416     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1417     # need to call `.task_done()` because we don't use `.join()`.
#    1418 else:
#    1419     while True:
# -> 1420         success, data = self._try_get_data()
#    1421         if success:
#    1422             return data
#
# File /local/scratch/MRI_Degad_Model/venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1251, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1238 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1239     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1240     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1248     # Returns a 2-tuple:
#    1249     #   (bool: whether successfully get data, any: data if successful else None)
#    1250     try:
# -> 1251         data = self._data_queue.get(timeout=timeout)
#    1252         return (True, data)
#    1253     except Exception as e:
#    1254         # At timeout and error, we manually check whether any worker has
#    1255         # failed. Note that this is the only mechanism for Windows to detect
#    1256         # worker failures.
#
# File ~/miniconda3/lib/python3.12/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~/miniconda3/lib/python3.12/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/miniconda3/lib/python3.12/multiprocessing/connection.py:440, in Connection._poll(self, timeout)
#     439 def _poll(self, timeout):
# --> 440     r = wait([self], timeout)
#     441     return bool(r)
#
# File ~/miniconda3/lib/python3.12/multiprocessing/connection.py:1135, in wait(object_list, timeout)
#    1132     deadline = time.monotonic() + timeout
#    1134 while True:
# -> 1135     ready = selector.select(timeout)
#    1136     if ready:
#    1137         return [key.fileobj for (key, events) in ready]
#
# File ~/miniconda3/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
# def visualize_batch(loader, num_samples=6, title="Batch Samples"):

#     plt.figure(figsize=(12, 2 * num_samples))
    
#     for i, batch in enumerate(loader):
#         images, labels = batch["image"], batch["label"]
        
#         # convert to numpy arrays (remove channel dimension)
#         images = images.numpy()
#         labels = labels.numpy()

#         batch_size = images.shape[0]
#         max_to_show = min(num_samples, batch_size)

#         for idx in range(max_to_show):
#             img = np.squeeze(images[idx])  # shape: (H, W, D) or (D, H, W)
#             lbl = np.squeeze(labels[idx])

#             # pick a slice along the last dimension
#             slice_index = img.shape[-1] // 2

#             # Show image
#             plt.subplot(max_to_show, 2, idx * 2 + 1)
#             plt.imshow(img[..., slice_index], cmap="gray")
#             plt.title(f"Image {idx+1}")
#             plt.axis("off")

#             # Show label
#             plt.subplot(max_to_show, 2, idx * 2 + 2)
#             plt.imshow(lbl[..., slice_index], cmap="gray")
#             plt.title(f"Label {idx+1}")
#             plt.axis("off")

#     plt.suptitle(title)
#     plt.tight_layout()
#     plt.show()

# visualize_batch(train_loader, num_samples=6, title="Train Batch Samples")

# %% [markdown]
# Model definition

# %%
# calculate channels and strides based on given parameters
channels = []
for i in range(depth):
    channels.append(filter)
    filter *=2
print("channels: ", channels)
strides = []
for i in range(depth-1):
    strides.append(2)
print("strides: ", strides)

# define model 
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=1,
    channels=channels,
    strides=strides,
    num_res_units=2,
    dropout=0.2,
    norm='BATCH'
).apply(monai.networks.normal_init).to(device)

trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# channels:  [64, 128, 256, 512]
# strides:  [2, 2, 2]

# %% [markdown]
# Define lr, optimization, epochs, loss

# %%
learning_rate = float(lr)

# common defaults
betas = (0.5, 0.999)

optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate, betas=betas)

best_model_path = f"{output_dir}/best_model.pt"
max_epochs = 1
patience = 22

loss = torch.nn.L1Loss().to(device)

train_losses = [float('inf')]
val_losses = [float('inf')]
best_val_loss = float('inf')
test_loss = 0

# %% [markdown]
# Train model

# %%
start = time.time()

for epoch in range(max_epochs):
    print(f"\nEpoch {epoch + 1}/{max_epochs}")
    model.train()

    train_loss_display = f"{train_losses[-1]:.4f}" if train_losses else "N/A"
    val_loss_display = f"{val_losses[-1]:.4f}" if val_losses else "N/A"

    progress_bar(
        index=epoch + 1,
        count=max_epochs,
        desc=f"epoch {epoch + 1}, training mae loss: {train_loss_display}, validation mae metric: {val_loss_display}",
        newline=True
    )

    # training
    avg_train_loss = 0

    print("--------Training--------")
    for batch in train_loader:
        # image is gad image, label is nogad image
        gad_images, nogad_images = batch["image"].to(device), batch["label"].to(device)
        optimizer.zero_grad() #resets optimizer to 0
        degad_images = model(gad_images)
        degad_images = degad_images[:, :, :image_size, :image_size, :image_size]
        
        train_loss = loss(degad_images, nogad_images)
        train_loss.backward() # computes gradients for each parameter based on loss
        optimizer.step() # updates the model weights using the gradient
        avg_train_loss += train_loss.item() 
   
    avg_train_loss /= len(train_loader) # average loss per current epoch 
    train_losses.append(avg_train_loss) # append total epoch loss divided by the number of training steps in epoch to loss list
    model.eval()
    
    print("--------Validation--------")
    # validation 
    with torch.no_grad(): #we do not update weights/biases in validation training, only used to assess current state of model
        avg_val_loss = 0 # will hold sum of all validation losses in epoch and then average
        for batch in val_loader: # iterating through dataloader
            gad_images, nogad_images = batch["image"].to(device), batch["label"].to(device)
            degad_images = model(gad_images)
            degad_images = degad_images[:, :, :image_size, :image_size, :image_size]

            val_loss = loss(degad_images, nogad_images)
            avg_val_loss += val_loss.item() 
        
        avg_val_loss /= len(val_loader)  # Average validation loss for the epoch
        val_losses.append(avg_val_loss) 

        if avg_val_loss < best_val_loss:
            print(f"Validation loss improved from {best_val_loss:.4f} to {avg_val_loss:.4f}. Saving model.")
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), best_model_path)
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1
            print(f"No improvement in validation loss. Best remains {best_val_loss:.4f}.")

        if epochs_without_improvement >= patience:
            print(f"Early stopping at epoch {epoch+1} due to no improvement in validation loss.")
            break
        
end = time.time()
total_time = end - start
print("time for training and validation: ", total_time)
# Out:
# Epoch 1/1
# 1/1 epoch 1, training mae loss: inf, validation mae metric: inf [==============================]
#
# --------Training--------
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Plot training metrics

# %%
# from original code 

with open (f'{output_dir}/model_stats.txt', 'w') as file:  
    file.write(f'Training time: {total_time:.2f} seconds\n') 
    file.write(f'Number of trainable parameters: {trainable_params}\n')

    if len(train_losses) > patience:
        file.write(f'Training loss (epoch {-patience}): {train_losses[-patience]:.4f}\n')
    else:
        file.write(f'Training loss (last epoch): {train_losses[-1]:.4f}\n')

    file.write(f'Validation loss (best): {best_val_loss:.4f}\n')
    
epochs = list(range(1, len(train_losses) + 1))
plt.figure(figsize=(12, 5))
plt.plot(epochs, train_losses, label="Training Loss")
plt.plot(epochs, val_losses, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig(f'{output_dir}/lossfunction.png')
plt.close()

# %% [markdown]
# Test model with sliding window

# %%
test_loss = 0 
home_dir = Path.home()

model.load_state_dict(torch.load(f'{home_dir}/graham/scratch/mri_degad/output_whole_images_new_data/image-256_batch-1_LR-0.0005_filter-64_depth-4_loss-ssim/best_model.pt', map_location=torch.device('cpu')))
model.eval()

output_dir_test = Path(output_dir) / "test"
output_dir_test.mkdir(parents=True, exist_ok=True)
with torch.no_grad():
    for i, batch in enumerate(test_loader):      
        gad_images, nogad_images = batch["image"].to(device), batch["label"].to(device)
        gad_paths = batch["image_filepath"]
        
        degad_images = sliding_window_inference(gad_images, image_size, 1, model)
        loss_value = loss(degad_images, gad_images)
        test_loss += loss_value.item()

        # to save the output files 
        # shape[0] gives number of images 
        for j in range(degad_images.shape[0]):
            gad_path = gad_paths[j] # test dictionary image file name
            print(gad_path)
            gad_nib = nib.load(gad_path)
            sub = Path(gad_path).name.split("_")[0]
            
            degad_name = f"{sub}_acq-degad_T1w.nii.gz" 
            nogad_name = f"{sub}_acq-nogad_T1w.nii.gz" 
            gad_name = f"{sub}_acq-gad_T1w.nii.gz"           
            
            # convert predicted output to NumPy
            degad_np = degad_images[j, 0].detach().cpu().numpy()
            nogad_np = nogad_images[j, 0].detach().cpu().numpy()
            gad_np = gad_images[j, 0].detach().cpu().numpy()

            # use original gad_affine on the image 
            gad_affine = gad_nib.affine if gad_nib is not None else np.eye(4)

            # create nifti images 
            degad_nib = nib.Nifti1Image(degad_np, gad_affine)
            nogad_nib = nib.Nifti1Image(nogad_np, gad_affine)
            gad_nib = nib.Nifti1Image(gad_np, gad_affine)

            # output directory in BIDS format
            subject_output_dir = f'{output_dir_test}/bids/{sub}/ses-pre/anat'
            os.makedirs(subject_output_dir, exist_ok=True)

            # save all images
            nib.save(degad_nib, os.path.join(subject_output_dir, degad_name))
            nib.save(nogad_nib, os.path.join(subject_output_dir, nogad_name))
            nib.save(gad_nib, os.path.join(subject_output_dir, gad_name)) 
    
    
print(f"Test Loss: {test_loss / len(test_loader):.4f}")
# Out:
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P140/ses-pre/normalize/sub-P140_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P054/ses-pre/normalize/sub-P054_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P147/ses-pre/normalize/sub-P147_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P152/ses-pre/normalize/sub-P152_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P125/ses-pre/normalize/sub-P125_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P035/ses-pre/normalize/sub-P035_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P109/ses-pre/normalize/sub-P109_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P111/ses-pre/normalize/sub-P111_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P108/ses-pre/normalize/sub-P108_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P154/ses-pre/normalize/sub-P154_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P024/ses-pre/normalize/sub-P024_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P065/ses-pre/normalize/sub-P065_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P020/ses-pre/normalize/sub-P020_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P079/ses-pre/normalize/sub-P079_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P030/ses-pre/normalize/sub-P030_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P036/ses-pre/normalize/sub-P036_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P139/ses-pre/normalize/sub-P139_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P122/ses-pre/normalize/sub-P122_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P172/ses-pre/normalize/sub-P172_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P075/ses-pre/normalize/sub-P075_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P133/ses-pre/normalize/sub-P133_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P023/ses-pre/normalize/sub-P023_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P017/ses-pre/normalize/sub-P017_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# /home/UWO/msnyde26/graham/scratch/degad_preprocessed_data/work/sub-P014/ses-pre/normalize/sub-P014_ses-pre_acq-gad_run-01_desc-normalize_minmax_T1w.nii.gz
# Test Loss: 0.0066
